# %% [markdown]
# # 코로나 전,후 영화 산업 동향 분석을 통한 영화 산업 추이 예측
#
# ## 데이터 수집 및 가공 그리고 시각화를 통해 4년간의 영화 산업  동향분석
# ## 코로나 이전과 코로나 시기 그리고 현재의 영화 데이터 분석을 통해 엔데믹 이후 영화 산업 예측
#
#
# ### 분석할 데이터
#
# - 박스오피스 (월별)
# - 좌석점유율 (기간별 - 월별)
# - 장르분포 & 점유율 통계 (월별)
# - 네이버 키워드에서 영화 순위(영화에 대한 관심도)
# - 코로나 거리두기 시행이 영화 산업에 미치는 영향 (영화관 시간제한 / 좌석수)
# - 월별 코로나 확진자
# - OTT 이용자
#
# **코로나 기준 : 정부 기관에서 발표한 시기 \
# 코로나 전 : 18년 4월 ~ 20년 3월 (2년)\
# 코로나 중 : 20년 4월 ~ 22년 3월 (2년)\
# 코로나 후 : 22년 4월 ~ 22년 6월 (3달)\

# %% [markdown]
# # 데이터 가공

# %% [markdown]
# ## 좌석 점유율 (기간별 - 월별)
# ### 지역: 전라북도 ~ 세종시

# %%
data= pd.read_excel(f'data/KOBIS_기간별_좌석점유율_2022-07-09.xlsx', engine='openpyxl',skiprows=1,skipfooter = 1)

data['date']='2022-06'
data['place'] = '전라북도'
data.head()
# Out:
#     순위                          영화명        개봉일  좌석판매율  좌석점유율       좌석수  \
# 0  1.0                       범죄도시 2 2022-05-18  0.186  0.009  730846.0
# 1  2.0  마녀(魔女) Part2. The Other One 2022-06-15  0.171  0.006  482410.0
# 2  2.0                 쥬라기 월드: 도미니언 2022-06-01  0.145  0.006  468689.0
# 3  2.0                      탑건: 매버릭 2022-06-22  0.126  0.006  458062.0
# 4  5.0                          브로커 2022-06-08  0.089  0.005  388825.0
#
#             매출액         누적매출액       관객수       누적관객수     date place
# 0  1.369618e+09  1.262375e+11  136151.0  12216638.0  2022-06  전라북도
# 1  8.177053e+08  2.495603e+10   82740.0   2425343.0  2022-06  전라북도
# 2  6.757527e+08  2.910183e+10   68153.0   2823283.0  2022-06  전라북도
# 3  6.026590e+08  2.322440e+10   57843.0   2183800.0  2022-06  전라북도
# 4  3.343014e+08  1.236483e+10   34786.0   1236006.0  2022-06  전라북도

# %%
place_list = ['전라북도', '전라남도','제주도','부산시', '대구시','대전시','울산시','인천시','광주시','세종시']

# for문을 이용해 저장한 데이터 불러오고 append로 취합
for i in range(1,10):
  a = pd.read_excel(f'data/KOBIS_기간별_좌석점유율_2022-07-09 ({i}).xlsx', engine='openpyxl',skiprows=4,skipfooter = 1)
  a['date'] = '2022-06'
  a['place'] = place_list[i]
  # b = 6
  # a['date']=f'2022-0{b}'
  # b+=1
  data = data.append(a)

data.to_csv('202206_2.csv', index='False')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       3 # for문을 이용해 저장한 데이터 불러오고 append로 취합
#       4 for i in range(1,10):
# ----> 5   a = pd.read_excel(f'data/KOBIS_기간별_좌석점유율_2022-07-09 ({i}).xlsx', engine='openpyxl',skiprows=4,skipfooter = 1)
#       6   a['date'] = '2022-06'
#       7   a['place'] = place_list[i]
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## data_2022_05

# %%
#data_2022_05
place_list = ['전라북도', '전라남도','제주도','부산시', '대구시','대전시','울산시','인천시','광주시','세종시']
date_list = ['2022-05','2022-04','2022-03','2022-02','2022-01','2021-12','2021-11','2021-10','2021-09','2021-08','2021-07','2021-06','2021-05']


data_2022_05= pd.DataFrame()
for i in range(0,10):
  a = pd.read_excel(f'data/KOBIS_기간별_좌석점유율_2022-07-09 ({i+10}).xlsx', engine='openpyxl',skiprows=4,skipfooter = 1)
  a['date'] = '2022-05'
  a['place'] = place_list[i]
  # b = 6
  # a['date']=f'2022-0{b}'
  # b+=1
  data_2022_05 = data_2022_05.append(a)

print(data_2022_05.shape)
data_2022_05.tail(4)

data.to_csv('202205.csv', index='False')
# Out:
# (758, 12)

# %%
# data_2022_04
place_list = ['전라북도', '전라남도','제주도','부산시', '대구시','대전시','울산시','인천시','광주시','세종시']
date_list = ['2022-05','2022-04','2022-03','2022-02','2022-01','2021-12','2021-11','2021-10','2021-09','2021-08','2021-07','2021-06','2021-05']


data_2022_04= pd.DataFrame()
for i in range(0,10):
  a = pd.read_excel(f'data/KOBIS_기간별_좌석점유율_2022-07-09 ({i+20}).xlsx', engine='openpyxl',skiprows=4,skipfooter = 1)
  a['date'] = '2022-04'
  a['place'] = place_list[i]
  # b = 6
  # a['date']=f'2022-0{b}'
  # b+=1
  data_2022_04 = data_2022_04.append(a)

print(data_2022_04.shape)
print(data_2022_04.tail(4))

data_2022_04.to_csv('202204.csv', index='False')
# Out:
# (856, 12)
#      순위           영화명        개봉일  좌석판매율  좌석점유율    좌석수      매출액        누적매출액  \
# 32  2.0      몬스터 아일랜드 2022-04-28  0.081    0.0  122.0  50000.0    2409000.0
# 33  2.0     아메리칸 저스티스 2022-04-07  0.074    0.0  134.0  70000.0    8050000.0
# 34  2.0  뱅드림! 팝핀' 드림! 2022-03-24  0.018    0.0  274.0  48000.0  116473360.0
# 35  2.0           스펜서 2022-03-16  0.015    0.0  318.0  45300.0  773825230.0
#
#      관객수    누적관객수     date place
# 32  10.0    489.0  2022-04   세종시
# 33  10.0   1150.0  2022-04   세종시
# 34   5.0  11875.0  2022-04   세종시
# 35   5.0  82016.0  2022-04   세종시

# %%
# data_2022_04
place_list = ['전라북도', '전라남도','제주도','부산시', '대구시','대전시','울산시','인천시','광주시','세종시']
date_list = ['2022-05','2022-04','2022-03','2022-02','2022-01','2021-12','2021-11','2021-10','2021-09','2021-08','2021-07','2021-06','2021-05']

def make_up(y,z):   #x:파일이름 y: 엑셀 파일 시작 숫자 z: data_list 위치
  start= pd.DataFrame()
  for i in range(0,10):
    a = pd.read_excel(f'data/KOBIS_기간별_좌석점유율_2022-07-09 ({i+y}).xlsx', engine='openpyxl',skiprows=4,skipfooter = 1)
    a['date'] = date_list[z]
    a['place'] = place_list[i]
    start = start.append(a)

  # print(start.shape)
  # print(start.tail(4))
  start.to_csv(f'{date_list[z]}.csv', index='False')

make_up(30, 2)   #x:파일이름 y: 엑셀 파일 시작 숫자 z: data_list 위치

# %%
# 21년 8월 ~ 22년 2월
date_list = ['2022-02','2022-01','2021-12','2021-11','2021-10','2021-09','2021-08']


for i in range(0,7):
  make_up((i+4)*10,i)   # y: 엑셀 파일 시작 숫자 z: data_list 위치

# %% [markdown]
# ## make_up 함수

# %%
# ~ 21년 7월

def make_up(y,z,D_list,file):   #x:파일이름 y: 엑셀 파일 시작 숫자 z: data_list 위치
  place_list = ['전라북도', '전라남도','제주도','부산시', '대구시','대전시','울산시','인천시','광주시','세종시']
  start= pd.DataFrame()

  for i in range(0,10):
    a = pd.read_excel(f'{file}/KOBIS_기간별_좌석점유율_2022-07-10 ({i+y}).xlsx', engine='openpyxl',skiprows=4,skipfooter = 1)
    a['date'] = D_list[z]
    a['place'] = place_list[i]
    start = start.append(a)
  start.to_csv(f'{D_list[z]}.csv', index='False')

# %% [markdown]
# ## 나머지 날짜 불러와서 합치기

# %%
#했음
date_list2 = [ '2020-08','2020-07','2020-06','2020-05','2020-04','2020-03','2020-02','2020-01','2019-12','2019-11','2019-10',
             
]

for i in range(len(date_list2)):
  make_up((i)*10,i,date_list2)   # y: 엑셀 파일 시작 숫자 z: data_list 위치

# %%
#했음
date_list3 = [ '2019-09','2019-08','2019-07','2019-06','2019-05','2019-04','2019-03','2019-02','2019-01'      
]

for i in range(len(date_list3)):
  make_up((i)*10,i,date_list3)   # y: 엑셀 파일 시작 숫자 z: data_list 위치

# %%
#201812_201804
#했음
date_list4 = [ '2018-12','2018-11','2018-10','2018-09','2018-08','2018-07','2018-06','2018-05','2018-04'
]

for i in range(len(date_list4)):
  make_up((i)*10,i,date_list4,'201812_201804')   # y: 엑셀 파일 시작 숫자 z: data_list 위치

# %%
# 202107_202009

date_list5 = [ '2021-07','2021-06','2021-05','2021-04','2021-03','2021-02','2021-01','2020-12','2020-11','2020-10','2020-09'  ]

for i in range(len(date_list)):
  make_up((i)*10,i,date_list5,'202107_202009')   # y: 엑셀 파일 시작 숫자 z: data_list 위치

# %% [markdown]
# ## 모든파일 합치기(df : total_data.csv)

# %%
#모든 파일 합치기

import os

path = './ddd/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝

file_list_py
## csv 파일들을 DataFrame으로 불러와서 concat

df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i)
    df = pd.concat([df,data])
    
df = df.reset_index(drop = True)
df
# Out:
#        Unnamed: 0   순위          영화명         개봉일  좌석판매율  좌석점유율       좌석수  \
# 0               0  1.0        더 배트맨  2022-03-01  0.034  0.008  461552.0
# 1               1  2.0  이상한 나라의 수학자  2022-03-09  0.042  0.006  346791.0
# 2               2  3.0        뜨거운 피  2022-03-23  0.037  0.003  205838.0
# 3               3  3.0           문폴  2022-03-16  0.027  0.003  192799.0
# 4               4  5.0   극장판 주술회전 0  2022-02-17  0.048  0.002  117430.0
# ...           ...  ...          ...         ...    ...    ...       ...
# 49351          42  3.0        베이비티스  2020-10-22  0.011  0.000     724.0
# 49352          43  3.0       포기와 베스  2020-10-06  0.019  0.000     408.0
# 49353          44  3.0      내 사랑 찾기  2020-10-22  0.007  0.000     516.0
# 49354          45  3.0      지옥의 오르페  2020-10-25  0.014  0.000     204.0
# 49355          46  3.0         나의이름  2020-10-14  0.003  0.000     331.0
#
#                매출액         누적매출액      관객수     누적관객수     date place
# ...

# %%
df.shape
df = df.drop(['Unnamed: 0','순위'], axis = 1)

# %%
df.head(3)
# Out:
#          title   open_date  seat_rate  seat_share  seat_qty          매출액  \
# 0        더 배트맨  2022-03-01      0.034       0.008  461552.0  155180460.0
# 1  이상한 나라의 수학자  2022-03-09      0.042       0.006  346791.0  132940220.0
# 2        뜨거운 피  2022-03-23      0.037       0.003  205838.0   73099820.0
#
#           누적매출액      관객수     누적관객수     date region
# 0  9.133703e+09  15759.0  884123.0  2022-03   전라북도
# 1  4.628560e+09  14584.0  487694.0  2022-03   전라북도
# 2  2.643288e+09   7821.0  276791.0  2022-03   전라북도

# %%
df.head(3)
# Out:
#            영화명         개봉일  좌석판매율  좌석점유율       좌석수          매출액         누적매출액  \
# 0        더 배트맨  2022-03-01  0.034  0.008  461552.0  155180460.0  9.133703e+09
# 1  이상한 나라의 수학자  2022-03-09  0.042  0.006  346791.0  132940220.0  4.628560e+09
# 2        뜨거운 피  2022-03-23  0.037  0.003  205838.0   73099820.0  2.643288e+09
#
#        관객수     누적관객수     date place
# 0  15759.0  884123.0  2022-03  전라북도
# 1  14584.0  487694.0  2022-03  전라북도
# 2   7821.0  276791.0  2022-03  전라북도

# %%
df.to_csv('total_data.csv')  # 파일로 저장

# %% [markdown]
# ## df파일 가공

# %%
data_df = pd.read_csv('total_data.csv')
data_df.head(3)
# Out:
#    Unnamed: 0          영화명         개봉일  좌석판매율  좌석점유율       좌석수          매출액  \
# 0           0        더 배트맨  2022-03-01  0.034  0.008  461552.0  155180460.0
# 1           1  이상한 나라의 수학자  2022-03-09  0.042  0.006  346791.0  132940220.0
# 2           2        뜨거운 피  2022-03-23  0.037  0.003  205838.0   73099820.0
#
#           누적매출액      관객수     누적관객수     date place
# 0  9.133703e+09  15759.0  884123.0  2022-03  전라북도
# 1  4.628560e+09  14584.0  487694.0  2022-03  전라북도
# 2  2.643288e+09   7821.0  276791.0  2022-03  전라북도

# %%
#필요없는 열 제거


data_df.drop(['Unnamed: 0','매출액','누적매출액','관객수','누적관객수'], axis = 1, inplace = True)
data_df.head(3)
# Out:
#            영화명         개봉일  좌석판매율  좌석점유율       좌석수     date place
# 0        더 배트맨  2022-03-01  0.034  0.008  461552.0  2022-03  전라북도
# 1  이상한 나라의 수학자  2022-03-09  0.042  0.006  346791.0  2022-03  전라북도
# 2        뜨거운 피  2022-03-23  0.037  0.003  205838.0  2022-03  전라북도

# %%
# 열 이름 재정의 (타 데이터와 통일 위해)
data_df.rename( columns = {'영화명': 'title', '개봉일':'open_date'},inplace=True)
data_df.rename( columns = {'좌석판매율': 'seat_rate', '좌석점유율':'seat_share','좌석수':'seat_qty','place':'region'},inplace=True)

# %%
# 시간(년-월) 분리하기
data_df['year'] = data_df.date.str.split('-').str[0]
data_df['month'] = data_df.date.str.split('-').str[1]
data_df.head(3)
# Out:
#          title   open_date  seat_rate  seat_share  seat_qty     date region  \
# 0        더 배트맨  2022-03-01      0.034       0.008  461552.0  2022-03   전라북도
# 1  이상한 나라의 수학자  2022-03-09      0.042       0.006  346791.0  2022-03   전라북도
# 2        뜨거운 피  2022-03-23      0.037       0.003  205838.0  2022-03   전라북도
#
#    year month
# 0  2022    03
# 1  2022    03
# 2  2022    03

# %%
# year, month 열 숫자형으로 변환 (문자 -> 숫자)
data_df.info()
data_df['year'] = pd.to_numeric(data_df['year'])
data_df['month'] = pd.to_numeric(data_df['month'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49356 entries, 0 to 49355
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       49356 non-null  object
#  1   open_date   44745 non-null  object
#  2   seat_rate   49356 non-null  float64
#  3   seat_share  49356 non-null  float64
#  4   seat_qty    49356 non-null  float64
#  5   date        49356 non-null  object
#  6   region      49356 non-null  object
#  7   year        49356 non-null  object
#  8   month       49356 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 3.4+ MB

# %%
# 열 순서 재배열
data_df = data_df[['year','month','region','title','open_date','seat_rate','seat_share','seat_qty']]
data_df.head(3)
# Out:
#    year  month region        title   open_date  seat_rate  seat_share  \
# 0  2022      3   전라북도        더 배트맨  2022-03-01      0.034       0.008
# 1  2022      3   전라북도  이상한 나라의 수학자  2022-03-09      0.042       0.006
# 2  2022      3   전라북도        뜨거운 피  2022-03-23      0.037       0.003
#
#    seat_qty
# 0  461552.0
# 1  346791.0
# 2  205838.0

# %%
# df.csv 파일로 저장
df.to_csv('final_data.csv')

# %% [markdown]
# ##장르

# %%
final_data = pd.read_csv('final_data.csv')
final_data.shape
# Out:
# (49356, 12)

# %%
genre2 = pd.read_csv('영화정보 리스트_2022-07-11 (2).csv',header = 4)
genre2.shape
# Out:
# (65531, 9)

# %%
col_name = ['영화명', '영화명(영문)', '제작연도', '제작국가', '유형', '장르', '제작상태', '감독', '제작사']
genre3 = pd.read_csv('영화정보 리스트_2022-07-11 (3).csv',names=col_name)
genre3.head(1)
# Out:
# (23094, 9)

# %%
genre2.columns
# Out:
# Index(['영화명', '영화명(영문)', '제작연도', '제작국가', '유형', '장르', '제작상태', '감독', '제작사'], dtype='object')

# %%
genre3.head(3)
# Out:
#          영화명       영화명(영문)    제작연도 제작국가  유형             장르 제작상태  \
# 0     엄마와 아들           URS  2009.0   독일  단편   애니메이션,가족,드라마   기타
# 1  꼬리는 내 친구!  My Happy End  2007.0   독일  단편  애니메이션,코미디,드라마   기타
# 2     신기한 친구        Pebble  2007.0   독일  단편      애니메이션,드라마   기타
#
#                     감독  제작사
# 0  모리츠 메이어호퍼,스티나 맥니콜라스  NaN
# 1              밀렌 비타노프  NaN
# 2       앨런 호프먼,요한 슈튜트먼  NaN

# %%
genre2.head(3)
# Out:
#             영화명  영화명(영문)    제작연도     제작국가  유형          장르  제작상태      감독  \
# 0     육사오(6/45)      NaN  2021.0       한국  장편         코미디  개봉예정     박규태
# 1  모로코 요리사: 타제카  Tazzeka  2018.0  프랑스,모로코  장편         코미디    기타     NaN
# 2           카라멜  Caramel  2007.0      프랑스  장편  멜로/로맨스,드라마    개봉  나딘 라바키
#
#                   제작사
# 0  (주)티피에스컴퍼니,(주)싸이더스
# 1                 NaN
# 2                 NaN

# %%
genre = genre2.append(genre3)

# %%
genre[genre['영화명']== '마녀']
# Out:
#       영화명                             영화명(영문)    제작연도 제작국가  유형  \
# 17379  마녀  The Witch : Part 1. The Subversion  2018.0   한국  장편
# 43921  마녀                          The Wicked  2013.0   한국  장편
#
#                    장르 제작상태   감독                    제작사
# 17379         미스터리,액션   개봉  박훈정  (주)영화사 금월,(주)페퍼민트앤컴퍼니
# 43921  공포(호러),스릴러,드라마   개봉  유영선          주식회사 흰수염고래영화사

# %%
final_data.head(3)
# Out:
#    Unnamed: 0        title   open_date  seat_rate  seat_share  seat_qty  \
# 0           0        더 배트맨  2022-03-01      0.034       0.008  461552.0
# 1           1  이상한 나라의 수학자  2022-03-09      0.042       0.006  346791.0
# 2           2        뜨거운 피  2022-03-23      0.037       0.003  205838.0
#
#            매출액         누적매출액      관객수     누적관객수     date region
# 0  155180460.0  9.133703e+09  15759.0  884123.0  2022-03   전라북도
# 1  132940220.0  4.628560e+09  14584.0  487694.0  2022-03   전라북도
# 2   73099820.0  2.643288e+09   7821.0  276791.0  2022-03   전라북도

# %%
genre.head(3)
# Out:
#             영화명  영화명(영문)    제작연도     제작국가  유형          장르  제작상태      감독  \
# 0     육사오(6/45)      NaN  2021.0       한국  장편         코미디  개봉예정     박규태
# 1  모로코 요리사: 타제카  Tazzeka  2018.0  프랑스,모로코  장편         코미디    기타     NaN
# 2           카라멜  Caramel  2007.0      프랑스  장편  멜로/로맨스,드라마    개봉  나딘 라바키
#
#                   제작사
# 0  (주)티피에스컴퍼니,(주)싸이더스
# 1                 NaN
# 2                 NaN

# %%
genre[genre['영화명']=='탑건: 매버릭']
# Out:
#          영화명            영화명(영문)    제작연도 제작국가  유형  장르 제작상태       감독  제작사
# 468  탑건: 매버릭  Top Gun: Maverick  2021.0   미국  장편  액션   개봉  조셉 코신스키  NaN

# %%
genre.drop(['영화명(영문)','제작연도','제작국가','제작상태','감독','제작사'],axis = 1, inplace = True)

# %%
genre.rename(columns={'영화명':'title','유형':'type','장르':'genre'}, inplace = True)
genre.head(10)
# Out:
#              title type           genre
# 0        육사오(6/45)   장편             코미디
# 1     모로코 요리사: 타제카   장편             코미디
# 2              카라멜   장편      멜로/로맨스,드라마
# 3            뒤틀린 집   장편  공포(호러),드라마,스릴러
# 4         전장의 A.I.   장편           다큐멘터리
# 5        아이를 위한 아이   장편              기타
# 6            더 빌리지   장편          공포(호러)
# 7  더 킬러: 죽어도 되는 아이   장편              액션
# 8        이집트 DJ 사와   장편          액션,코미디
# 9           그을린 사랑   장편             드라마

# %%
# 공백때문에 merge할때 에러가 나서 양 옆 공백 제거
genre['title']=genre['title'].str.strip()

# %%
genre.head(3)
# Out:
#           title type       genre
# 0     육사오(6/45)   장편         코미디
# 1  모로코 요리사: 타제카   장편         코미디
# 2           카라멜   장편  멜로/로맨스,드라마

# %%
#장르 데이터 저장
genre.to_csv('genre.csv')

# %%
genre.shape
# Out:
# (88625, 3)

# %%
genre.drop_duplicates(['title'])
genre.shape
# Out:
# (88625, 3)

# %%
genre.nunique()
# Out:
# title    81560
# type         4
# genre     2050
# dtype: int64

# %%
genre[genre['title'] == '마녀']
# Out:
#       title type            genre
# 17379    마녀   장편          미스터리,액션
# 43921    마녀   장편   공포(호러),스릴러,드라마
# 7131     마녀   장편  드라마,성인물(에로),스릴러

# %% [markdown]
# ## 장르랑 합치기

# %%
df.head(3)

# %%
t = pd.merge(df,genre1,on=['title'], how = 'left')
t.head(3)

# %%
genre1.head(2)
# Out:
#                             title type   genre
# 0  극장판 포켓몬스터DP: 기라티나와 하늘의 꽃다발 쉐이미   장편   애니메이션
# 1                          셀링 이소벨   장편  범죄,스릴러

# %%
genre1.isnull().sum()
# Out:
# title      0
# type      21
# genre    237
# dtype: int64

# %%
t.drop(['Unnamed: 0'], axis = 1, inplace = True)
t.head(2)
# Out:
#    year  month region                        title   open_date  seat_rate  \
# 0  2022      6   전라북도                       범죄도시 2  2022-05-18      0.186
# 1  2022      6   전라북도  마녀(魔女) Part2. The Other One  2022-06-15      0.171
#
#    seat_share  seat_qty type  genre
# 0       0.009  730846.0   장편  범죄,액션
# 1       0.006  482410.0  NaN    NaN

# %%
t.to_csv('total_data.csv')

# %%
t.shape
# Out:
# (54718, 10)

# %% [markdown]
# # 장르 데이터 합치기

# %%
f_l = ['2018년 9월.csv',
 '2018년 7월.csv',
 '2018년 12월.csv',
 '2018년 11월.csv',
 '2018년 5월.csv',
 '2018년 8월.csv',
 '2018년 10월.csv',
 '2018년 6월.csv',
 '2018년 4월.csv']

path = 'genre/genre/After/2018/'
g1 = pd.read_csv(path+f_l[0],encoding='cp949',skipfooter = 1)
g2 = pd.read_csv(path+f_l[1],encoding='cp949',skipfooter = 1)
g3 = pd.read_csv(path+f_l[2],encoding='cp949',skipfooter = 1)
g4 = pd.read_csv(path+f_l[3],encoding='cp949',skipfooter = 1)
g5 = pd.read_csv(path+f_l[4],encoding='cp949',skipfooter = 1)
g6 = pd.read_csv(path+f_l[5],encoding='cp949',skipfooter = 1)
g7 = pd.read_csv(path+f_l[6],encoding='cp949',skipfooter = 1)
g8 = pd.read_csv(path+f_l[7],encoding='cp949',skipfooter = 1)
#

# %%
g5=g5.iloc[ : , :6]
g5

df = pd.DataFrame()
df  = pd.concat([df,g1])
df  = pd.concat([df,g2])
df  = pd.concat([df,g3])
df  = pd.concat([df,g4])
df  = pd.concat([df,g5])
df  = pd.concat([df,g6])
df  = pd.concat([df,g7])
df1  = pd.concat([df,g8])

# %%
#모든 파일 합치기

import os

path = 'genre/genre/After/2019/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝

file_list_py
## csv 파일들을 DataFrame으로 불러와서 concat

df2 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i,encoding='cp949',skipfooter = 1)
    df2 = pd.concat([df2,data])
    
df2 = df2.reset_index(drop = True)
df2.head(3)
# Out:
#      년도  월     장르   작품편수     총 이용건수   이용점유율
# 0  2019  6     액션  2,207  1,119,733  22.60%
# 1  2019  6    드라마  3,804    973,901  19.70%
# 2  2019  6  애니메이션  1,058    560,243  11.30%

# %%
df2[df2['월'].isnull()]
# Out:
# Empty DataFrame
# Columns: [년도, 월, 장르, 작품편수, 총 이용건수, 이용점유율]
# Index: []

# %%
#모든 파일 합치기 함수


def merge_all(x):   


  path = f'genre/genre/After/{x}/'
  file_list = os.listdir(path)
  file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝

  file_list_py
  ## csv 파일들을 DataFrame으로 불러와서 concat

  y = pd.DataFrame()
  for i in file_list_py:
      data = pd.read_csv(path + i,encoding='cp949',skipfooter = 1)
      y = pd.concat([y,data])
      print(y)
      
  y = y.reset_index(drop = True)
  return y
  y.head(3)

# %%
df3 = merge_all(2020)

# %%
df3[df3['월'].isnull()]
# Out:
# Empty DataFrame
# Columns: [년도, 월, 장르, 작품편수, 총 이용건수, 이용점유율]
# Index: []

# %%
df3.head(3)
# Out:
#      년도  월     장르   작품편수     총 이용건수   이용점유율
# 0  2020  2    드라마  4,039  2,129,138  32.00%
# 1  2020  2     액션  2,405  1,039,506  15.60%
# 2  2020  2  애니메이션  1,088  1,015,163  15.20%

# %%
#모든 파일 합치기 함수


def merge_ing(x):   


  path = f'genre/genre/ing/{x}/'
  file_list = os.listdir(path)
  file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝

  file_list_py
  ## csv 파일들을 DataFrame으로 불러와서 concat

  y = pd.DataFrame()
  for i in file_list_py:
      data = pd.read_csv(path + i,encoding='cp949',skipfooter = 1)
      y = pd.concat([y,data])

      
  y = y.reset_index(drop = True)
  return y
  y.head(3)

# %%
df4 = merge_ing(2022)
df5 = merge_ing(2021)
df6 = merge_ing(2020)

# %%
df4.info()

# %%
df6[df6['월'].isnull()]
# Out:
# Empty DataFrame
# Columns: [년도, 월, 장르, 작품편수, 총 이용건수, 이용점유율]
# Index: []

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      252 non-null    int64
#  1   월       252 non-null    int64
#  2   장르      252 non-null    object
#  3   작품편수    252 non-null    object
#  4   총 이용건수  252 non-null    object
#  5   이용점유율   252 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 11.9+ KB

# %%
df_list = [df1,df2,df3,df4,df5,df6]

# genre_total = pd.DataFrame()
# for i in df_list:
#   genre_total = genre_total.append(i)



genre_total = pd.concat(df_list)
genre_total
# Out:
#        년도  월        장르   작품편수     총 이용건수   이용점유율
# 0    2018  9        액션  2,106  1,487,260  24.80%
# 1    2018  9       드라마  3,774    970,147  16.20%
# 2    2018  9     애니메이션  1,047    750,333  12.50%
# 3    2018  9       판타지    166    595,012   9.90%
# 4    2018  9    멜로/로맨스  2,165    416,129   6.90%
# ..    ... ..       ...    ...        ...     ...
# 163  2020  4     다큐멘터리    494     27,336   0.60%
# 164  2020  4        기타    546     25,376   0.60%
# 165  2020  4       뮤지컬     44      6,695   0.20%
# 166  2020  4  서부극(웨스턴)     52      2,970   0.10%
# 167  2020  4        공연     18      1,311   0.00%
#
# [966 rows x 6 columns]

# %%
genre_total.info()   # 987 rows × 6 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 966 entries, 0 to 167
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      966 non-null    int64
#  1   월       966 non-null    int64
#  2   장르      966 non-null    object
#  3   작품편수    966 non-null    object
#  4   총 이용건수  966 non-null    object
#  5   이용점유율   966 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 52.8+ KB

# %%
genre_total.rename({'년도':'year','월':'month','장르':'genre','작품편수':'number_movie','총 이용건수': 't_use','이용점유율':'share'
                    }, axis = 1, inplace = True)

# %%
# genre_total.drop('Unnamed: 0', axis = 1, inplace = True)
genre_total.head(1)
# Out:
#          year month genre number_movie    t_use  share
# 0  2018-01-01     9    액션        2,106  1487260   24.8

# %%
genre_total.isnull().sum()
# Out:
# year            0
# month           0
# genre           0
# number_movie    0
# t_use           0
# share           0
# dtype: int64

# %%
genre_total.to_csv('genre_total.csv')

# %%
genre_total[genre_total['년도'] == 2022]
# Out:
#       년도    월        장르   작품편수   총 이용건수   이용점유율
# 0   2022  1.0        액션  2,739  736,423  29.10%
# 1   2022  1.0     애니메이션  1,229  466,282  18.40%
# 2   2022  1.0        범죄    551  386,315  15.30%
# 3   2022  1.0       드라마  4,750  261,060  10.30%
# 4   2022  1.0    멜로/로맨스  3,674  140,234   5.60%
# ..   ...  ...       ...    ...      ...     ...
# 58  2022  3.0        가족    109   10,531   0.60%
# 59  2022  3.0        사극    103    9,369   0.50%
# 60  2022  3.0  서부극(웨스턴)     33    2,576   0.10%
# 61  2022  3.0       뮤지컬     43    1,737   0.10%
# 62  2022  3.0        공연     19    1,011   0.10%
#
# [63 rows x 6 columns]

# %% [markdown]
# # 시각화 _ 장르

# %% [markdown]
# ## 장르 데이터 형변환

# %%
total_list = pd.read_csv('total_list.csv')
boxoffice = pd.read_csv('boxoffice.csv') 
genre_total = pd.read_csv('genre_total.csv',  thousands = ',')   #천단위 숫자기호 제거

# %%
total_list.drop(['new'],axis=1, inplace=True)

# %%
genre_total.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
genre_total.head(3)
# Out:
#          year  month  genre  number_movie    t_use  share
# 0  2018-01-01      9     액션          2106  1487260   24.8
# 1  2018-01-01      9    드라마          3774   970147   16.2
# 2  2018-01-01      9  애니메이션          1047   750333   12.5

# %%
genre_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          966 non-null    object
#  1   month         966 non-null    int64
#  2   genre         966 non-null    object
#  3   number_movie  966 non-null    int64
#  4   t_use         966 non-null    int64
#  5   share         966 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 45.4+ KB

# %%
# 타입 변환!!!
# genre_total['t_use'] = genre_total['t_use'].str.replace(',', '').astype('int')   # 천단위 구분기호 제거
# genre_total['share'] = genre_total['share'].str.replace('%', '').astype('float')

# %%
# obejct '2018-01-01'을 datetime으로 변환 (힘들었다..)
# 1.pd.to_datetime으로 새로운 칼럼생성
#2. 새로운칼럼이 여전히 '2018-01-01'이라면, .dt.year  로 년만 가져오게 새로운 칼럼 또 추가
#3. 필요없는 행 제거
genre_total['Year'] = pd.to_datetime(genre_total['year'])
genre_total['yeaR']=genre_total['Year'].dt.year

# %%
genre_total.head()
# Out:
#    month   genre  number_movie    t_use  share  year
# 0      9      액션          2106  1487260   24.8  2018
# 1      9     드라마          3774   970147   16.2  2018
# 2      9   애니메이션          1047   750333   12.5  2018
# 3      9     판타지           166   595012    9.9  2018
# 4      9  멜로/로맨스          2165   416129    6.9  2018

# %%
genre_total.drop(['year','Year'
            ],axis = 1, inplace = True)

# %%
genre_total.rename({'yeaR':'year'}, axis=1, inplace= True)

# %%
genre_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   month         966 non-null    object
#  1   genre         966 non-null    object
#  2   number_movie  966 non-null    int64
#  3   t_use         966 non-null    int64
#  4   share         966 non-null    float64
#  5   year          966 non-null    int64
#  6   Month         966 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 53.0+ KB

# %%
final_g_t = genre_total

# %% [markdown]
# ## 시각화

# %%
final_g_t

#number_movie	: 작품편수
#t_use	: 	총 이용건수
#share : 	이용점유율
# Out:
#      month     genre  number_movie    t_use  share  year
# 0        9        액션          2106  1487260   24.8  2018
# 1        9       드라마          3774   970147   16.2  2018
# 2        9     애니메이션          1047   750333   12.5  2018
# 3        9       판타지           166   595012    9.9  2018
# 4        9    멜로/로맨스          2165   416129    6.9  2018
# ..     ...       ...           ...      ...    ...   ...
# 961      4     다큐멘터리           494    27336    0.6  2020
# 962      4        기타           546    25376    0.6  2020
# 963      4       뮤지컬            44     6695    0.2  2020
# 964      4  서부극(웨스턴)            52     2970    0.1  2020
# 965      4        공연            18     1311    0.0  2020
#
# [966 rows x 6 columns]

# %%
# 인기 장르 TOP 5 (각 년도별 인기 장르 - 원형 그래프)

# 2018년도
ascd1 = final_g_t.sort_values(by ='t_use',ascending=False )
yearly_2018_top5 = ascd1[ascd1['year']==2018].head(5)

#2019 년도
ascd2 = final_g_t.sort_values(by ='t_use',ascending=False )
yearly_2019_top5 = ascd2[ascd2['year']==2019].head(5)
#2020년도
ascd3 = final_g_t.sort_values(by ='t_use',ascending=False )
yearly_2020_top5 = ascd3[ascd3['year']==2020].head(5)
# 2021년도
ascd4 = final_g_t.sort_values(by ='t_use',ascending=False )
yearly_2021_top5 = ascd4[ascd4['year']==2021].head(5)
# 2022년도
ascd5 = final_g_t.sort_values(by ='t_use',ascending=False )
yearly_2022_top5 = ascd5[ascd5['year']==2022].head(5)
# df_sort_group_top3 = df.sort_values(by="val", ascending=False).groupby("grp").head(3)

# %%
ascd1[ascd1['year']==2018].head(5)
# Out:
#     month  genre  number_movie    t_use  share  year
# 84      5     액션          3103  4999551   30.2  2018
# 85      5  애니메이션          1448  2546931   15.4  2018
# 86      5     범죄           646  2014684   12.2  2018
# 21      7     액션          2084  1925737   30.2  2018
# 87      5    드라마          5724  1900040   11.5  2018

# %%
plt.pie(yearly_2018_top5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-760-6b715c29ed5a> in <module>()
# ----> 1 plt.pie(yearly_2018_top5)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
sns.pairplot(yearly_2018_top5)

# %%
a= final_g_t[final_g_t['year']==2018]
a.채ㅣ.gropuby('genre').sum()['genre']
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-757-8d6f7983133c> in <module>()
#       2
#       3 a= final_g_t[final_g_t['year']==2018]
# ----> 4 a.col.gropuby('genre').sum()['genre']
#       5 a
#       6
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'col'

# %%
import matplotlib as mpl

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


mpl.rcParams['axes.unicode_minus'] = False

# %%
# 코랩
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 런타임 재시작

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc("font",family="font_name")
# fig, ax = plt.subplots(2,1)  #한 셀에 그릴 그래프 갯수 _ 도화지

g = final_g_t.groupby(['year'])
g.head()

# ascd1 = final_g_t.sort_values(by ='t_use',ascending=False )
# yearly_2018_top5 = ascd1[ascd1['year']==2018].head(5)
# Out:
#      month   genre  number_movie    t_use  share  year
# 0        9      액션          2106  1487260   24.8  2018
# 1        9     드라마          3774   970147   16.2  2018
# 2        9   애니메이션          1047   750333   12.5  2018
# 3        9     판타지           166   595012    9.9  2018
# 4        9  멜로/로맨스          2165   416129    6.9  2018
# 168      6      액션          2207  1119733   22.6  2019
# 169      6     드라마          3804   973901   19.7  2019
# 170      6   애니메이션          1058   560243   11.3  2019
# 171      6      범죄           486   533950   10.8  2019
# 172      6     코미디          1362   515032   10.4  2019
# 420      2     드라마          4039  2129138   32.0  2020
# 421      2      액션          2405  1039506   15.6  2020
# 422      2   애니메이션          1088  1015163   15.2  2020
# 423      2     코미디          1411   624435    9.4  2020
# 424      2    어드벤처           205   361069    5.4  2020
# 483      1      액션          2739   736423   29.1  2022
# ...

# %%
final_g_t.plot(figsize = (10,10))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
final_g_t
# Out:
#      month     genre  number_movie    t_use  share  year
# 0        9        액션          2106  1487260   24.8  2018
# 1        9       드라마          3774   970147   16.2  2018
# 2        9     애니메이션          1047   750333   12.5  2018
# 3        9       판타지           166   595012    9.9  2018
# 4        9    멜로/로맨스          2165   416129    6.9  2018
# ..     ...       ...           ...      ...    ...   ...
# 961      4     다큐멘터리           494    27336    0.6  2020
# 962      4        기타           546    25376    0.6  2020
# 963      4       뮤지컬            44     6695    0.2  2020
# 964      4  서부극(웨스턴)            52     2970    0.1  2020
# 965      4        공연            18     1311    0.0  2020
#
# [966 rows x 6 columns]

# %%
final_g_t[final_g_t['year'] == 2018]['genre'].value_counts()
# Out:
# 액션          8
# 사극          8
# 서부극(웨스턴)    8
# 성인물(에로)     8
# 전쟁          8
# 다큐멘터리       8
# 가족          8
# 기타          8
# 어드벤처        8
# 뮤지컬         8
# SF          8
# 드라마         8
# 공포(호러)      8
# 미스터리        8
# 코미디         8
# 범죄          8
# 스릴러         8
# 멜로/로맨스      8
# 판타지         8
# 애니메이션       8
# 공연          8
# Name: genre, dtype: int64

# %%
final_g_t[(final_g_t['year'] == 2018) & (final_g_t['genre']=='액션') ]
# \.value_counts()
# Out:
#      month genre  number_movie    t_use  share  year
# 0        9    액션          2106  1487260   24.8  2018
# 21       7    액션          2084  1925737   30.2  2018
# 42      12    액션          2169  1724675   24.0  2018
# 64      11    액션          2129  1009412   17.7  2018
# 84       5    액션          3103  4999551   30.2  2018
# 105      8    액션          2106  1819162   26.5  2018
# 126     10    액션          2131  1359890   25.0  2018
# 147      6    액션          2021  1351117   27.3  2018

# %%
final_g_t[final_g_t['year'] == 2019]['genre'].value_counts()
# Out:
# 액션          12
# 전쟁          12
# 서부극(웨스턴)    12
# 뮤지컬         12
# 성인물(에로)     12
# 기타          12
# 다큐멘터리       12
# 사극          12
# 가족          12
# 어드벤처        12
# 판타지         12
# 드라마         12
# 미스터리        12
# SF          12
# 스릴러         12
# 공포(호러)      12
# 멜로/로맨스      12
# 코미디         12
# 범죄          12
# 애니메이션       12
# 공연          12
# Name: genre, dtype: int64

# %%
# plt.bar()
# plt.pie()
# plt.hist()
# plt.scatter()
# plt.boxplot()

# %%
plt.pie(final_g_t['genre'].value_counts())

# %%
y_c = final_g_t.groupby('year').count()
y_c
# Out:
#       month  genre  number_movie  t_use  share
# year
# 2018    168    168           168    168    168
# 2019    252    252           252    252    252
# 2020    231    231           231    231    231
# 2021    252    252           252    252    252
# 2022     63     63            63     63     63

# %%
plt.plot(y_c['number_movie'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# 2개 이상의 컬럼으로 그룹
y_g = final_g_t.groupby(['year','genre']).count()
y_g
# y_g['year'] == '2018'
# Out:
#              month  number_movie  t_use  share
# year genre
# 2018 SF          8             8      8      8
#      가족          8             8      8      8
#      공연          8             8      8      8
#      공포(호러)      8             8      8      8
#      기타          8             8      8      8
# ...            ...           ...    ...    ...
# 2022 액션          3             3      3      3
#      어드벤처        3             3      3      3
#      전쟁          3             3      3      3
#      코미디         3             3      3      3
#      판타지         3             3      3      3
#
# [105 rows x 4 columns]

# %%
y_g = final_g_t.groupby(['year','genre'])['genre'].count()
y_g.head()
# Out:
# year  genre
# 2018  SF        8
#       가족        8
#       공연        8
#       공포(호러)    8
#       기타        8
# Name: genre, dtype: int64

# %%
final_g_t['genre'].value_counts()
# Out:
# 액션          46
# 사극          46
# 서부극(웨스턴)    46
# 성인물(에로)     46
# 전쟁          46
# 다큐멘터리       46
# 가족          46
# 기타          46
# 어드벤처        46
# 뮤지컬         46
# SF          46
# 드라마         46
# 공포(호러)      46
# 미스터리        46
# 코미디         46
# 범죄          46
# 스릴러         46
# 멜로/로맨스      46
# 판타지         46
# 애니메이션       46
# 공연          46
# Name: genre, dtype: int64

# %%
final_g_t['genre'].nunique()
# Out:
# 21

# %%
21*46
# Out:
# 966

# %%
final_g_t.shape
# Out:
# (966, 6)
